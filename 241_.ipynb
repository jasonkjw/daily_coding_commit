# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/241_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 241
import datetime
now = datetime.datetime.now()
print(now)
print(type(now))
# Out:
# 2026-02-08 09:27:59.683688
# <class 'datetime.datetime'>

# %%
# 242
import datetime
now = datetime.datetime.now()
print(type(now))
# Out:
# <class 'datetime.datetime'>

# %%
# 243
import datetime
now = datetime.datetime.now()
for day in range(5,0,-1):
  delta = datetime.timedelta(days=day)
  date = now - delta
  print(date)
# Out:
# 2026-02-03 09:34:46.979431
# 2026-02-04 09:34:46.979431
# 2026-02-05 09:34:46.979431
# 2026-02-06 09:34:46.979431
# 2026-02-07 09:34:46.979431

# %%
import datetime
now = datetime.datetime.now()
print(now.strftime("%H:%M:%S"))
# Out:
# 09:48:53
