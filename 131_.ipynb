# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/131_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 131
과일 = ["사과", "귤", "수박"]
for 변수 in 과일:
    print(변수)
# Out:
# 사과
# 귤
# 수박

# %%
# 132
과일 = ["사과", "귤", "수박"]
for 변수 in 과일:
  print("#####")
# Out:
# #####
# #####
# #####

# %%
# 133
for 변수 in ["A","B","C"]:
  print(변수)
# Out:
# A
# B
# C

# %%
# 134
for 변수 in ["A", "B", "C"]:
  print("출력:", 변수)

# %%
# 135
for 변수 in ["A", "B", "C"]:
  b = 변수.lower()
  print("변환:", b)

# %%
# 136
for 변수 in [10,20,30]:
  print(변수)
# Out:
# 10
# 20
# 30

# %%
# 137
for 변수 in [10,20,30]:
  print(변수)
# Out:
# 10
# 20
# 30

# %%
# 138
for 변수 in [10,20,30]:
  print("------")
# Out:
# ------
# ------
# ------

# %%
# 139
print("++++")
for 변수 in [10,20,30]:
  print(변수)
# Out:
# ++++
# 10
# 20
# 30

# %%
#140
for i in range(0, 4):
  print("------")
# Out:
# ------
# ------
# ------
# ------
