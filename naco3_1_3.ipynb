# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco3_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print((3>0) and (3>5))
print((3>0) & (3>5))
print((3>0) or (3>5))
print((3>0) | (3>5))
print(not(1 != 3 ))
# Out:
# False
# False
# True
# True
# False

# %%
number = 2 + 3 * 4
print(number)
number += 2
print(number)
number /= 2
print(number)
number **= 2
print(number)
number //= 2
print(number)
number %= 2
print(number)
# Out:
# 14
# 16
# 8.0
# 64.0
# 32.0
# 0.0
