# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco2_4_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(type(3))
# Out:
# <class 'int'>

# %%
print(type("3"))
# Out:
# <class 'str'>

# %%
print(type(3.5))
# Out:
# <class 'float'>

# %%
print(type(str(3)))
# Out:
# <class 'str'>
