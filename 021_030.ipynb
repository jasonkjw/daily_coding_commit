# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/021_030.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 021
letters = 'python'
print(letters[0], letters[2])
# Out:
# p t

# %%
# 022
license_plate = "24가 2210"
print(license_plate[-4:])
# Out:
# 2210

# %%
# 023
string = "홀짝홀짝홀짝"
print(string[0::2])
# Out:
# 홀홀홀

# %%
# 024
string = "PYTHON"
print(string[::-1])
# Out:
# NOHTYP

# %%
# 025
phone_number = "010-1111-2222"
print(phone_number.replace('-',' '))
# Out:
# 010 1111 2222

# %%
# 027
url = "http://sharebook.kr"
print(url.split('.')[-1])
# Out:
# kr

# %%
# 028
lang = 'python'
lang[0] = 'P'
print(lang)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1048442206.py in <cell line: 0>()
#       1 # 028
#       2 lang = 'python'
# ----> 3 lang[0] = 'P'
#       4 print(lang)
#
# TypeError: 'str' object does not support item assignment

# %%
# 029
string = 'abcdfe2a354a32a'
print(string.replace('a','A'))
# Out:
# Abcdfe2A354A32A

# %%
# 030
string = 'abcd'
string.replace('b', 'B')
print(string)
# Out:
# abcd

# %%
# 031
a = "3"
b = "4"
print(a + b)
# Out:
# 34

# %%
# 032
print("Hi" * 3)
# Out:
# HiHiHi

# %%
# 033
print('-' * 80)
# Out:
# --------------------------------------------------------------------------------

# %%
#034
t1 = 'python'
t2 = 'java'
print((t1+' '+t2+' ')*4)
# Out:
# python java python java python java python java

# %%
# 035
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13
print("이름: %s 나이: %d" %(name1, age1))
print("이름: %s 나이: %d" %(name2, age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
# 036
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13
print("이름: {} 나이: {}".format(name1,age1))
print("이름: {} 나이: {}".format(name2,age2))
# Out:
# 이름: 김민수 나이: 10
# 이름: 이철희 나이: 13

# %%
# 037
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13
print(f"이름: {name1} 나이: {age1}")
print(f"이름: {name2} 나이: {age2}")

# %%
# 038
상장주식수 = "5,969,782,550"
print(int(상장주식수.replace(',','')))
# Out:
# 5969782550

# %%
# 039
분기 = "2020/03(E) (IFRS연결)"
print(분기[:7])
# Out:
# 2020/03

# %%
# 040
data = "   삼성전자    "
print(data.strip())
# Out:
# 삼성전자

# %%
# 041
ticker = "btc_krw"
print(ticker.upper())
# Out:
# BTC_KRW

# %%
#042
ticker = "BTC_KRW"
print(ticker.lower())
# Out:
# btc_krw

# %%
a = "hello"
print(a.capitalize())
# Out:
# Hello

# %%
# 044
file_name = "보고서.xlsx"
print(file_name.endswith("xlsx"))
# Out:
# True

# %%
# 045
file_name = "보고서.xlsx"
file_name.endswith(("xlsx", "xls"))
# Out:
# True

# %%
# 046
file_name = "2020_보고서.xlsx"
file_name.startswith("2020")
# Out:
# True

# %%
# 047
a = "hello world"
print(a.split())
# Out:
# ['hello', 'world']

# %%
# 048
ticker = "btc_krw"
print(ticker.split('_'))
# Out:
# ['btc', 'krw']

# %%
# 049
date = "2020-05-01"
print(date.split('-'))
# Out:
# ['2020', '05', '01']

# %%
# 050
data = "039490     "
print(data.strip())
# Out:
# 039490
