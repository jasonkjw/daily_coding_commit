# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco5_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_set = {1,2,3,3,4,5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
java = {"푸", "피글렛", "티거"}
python = set(["푸", "이요르"])
print(java & python)
print(java.intersection(python))
print(java | python)
print(java.union(python))
print(java - python)
print(java.difference(python))
python.add("피글렛")
print(python)
java.remove("피글렛")
print(java)
# Out:
# {'푸'}
# {'푸'}
# {'티거', '푸', '피글렛', '이요르'}
# {'티거', '푸', '피글렛', '이요르'}
# {'티거', '피글렛'}
# {'티거', '피글렛'}
# {'푸', '피글렛', '이요르'}
# {'티거', '푸'}
