# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco9_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class ParkingManager:
  def __init__(self, capacity):
    self.capacity = capacity
    self.count = 0
    print(f"총 {capacity} 대를 등록할 수 있습니다.")

  def register(self):
    if self.count >= self.capacity:
      print("더 이상 등록할 수 없습니다.")
      return
    self.count += 1
    print(f"차량 신규 등록 ({self.count}/{self.capacity})")

manager = ParkingManager(5)
for i in range(6):
  manager.register()
# Out:
# 총 5 대를 등록할 수 있습니다.
# 차량 신규 등록 (1/5)
# 차량 신규 등록 (2/5)
# 차량 신규 등록 (3/5)
# 차량 신규 등록 (4/5)
# 차량 신규 등록 (5/5)
# 더 이상 등록할 수 없습니다.
