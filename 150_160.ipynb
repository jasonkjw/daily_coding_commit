# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/150_160.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 151
리스트 = [3, -20, -3, 44]
for i in 리스트:
  if i < 0:
    print(i)
# Out:
# -20
# -3

# %%
# 152
리스트 = [3, 100, 23, 44]
for i in 리스트:
  if i%3 == 0:
    print(i)
# Out:
# 3

# %%
# 153
리스트 = [13, 21, 12, 14, 30, 18]
for i in 리스트:
  if i < 20:
    if i % 3 == 0:
      print(i)
# Out:
# 12
# 18

# %%
# 154
리스트 = ["I", "study", "python", "language", "!"]
for i in 리스트:
  if len(i) >= 3:
    print(i)
# Out:
# study
# python
# language

# %%
# 155
리스트 = ["A", "b", "c", "D"]
for i in 리스트:
  if i.isupper() == True:
    print(i)
# Out:
# A
# D

# %%
# 156
리스트 = ["A", "b", "c", "D"]
for i in 리스트:
  if i. islower() == True:
    print(i)
# Out:
# b
# c

# %%
# 157
리스트 = ['dog', 'cat', 'parrot']
for i in 리스트:
  print(i[0].upper()+i[1:])
# Out:
# Dog
# Cat
# Parrot

# %%
# 158
리스트 = ['hello.py', 'ex01.py', 'intro.hwp']
for i in 리스트:
  print(i.split('.')[0])
# Out:
# hello
# ex01
# intro

# %%
# 159
리스트 = ['intra.h', 'intra.c', 'define.h', 'run.py']
for i in 리스트:
  if i.split('.')[-1] == 'h':
    print(i)
# Out:
# intra.h
# define.h

# %%
# 160
리스트 = ['intra.h', 'intra.c', 'define.h', 'run.py']
for i in 리스트:
  if i.split('.')[-1] == 'c' or i.split('.')[-1] == 'h':
    print(i)
# Out:
# intra.h
# intra.c
# define.h
