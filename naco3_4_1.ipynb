# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco3_4_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(abs(-5))
print(pow(4,2))
print(max(5,12))
print(min(5,12))
print(round(3.15))
print(round(4.1235, 2))
# Out:
# 5
# 16
# 12
# 5
# 3
# 4.12

# %%
#3.4.2
from math import *
result = floor(4.99)
print(result)
result = ceil(3.14)
print(result)
result = sqrt(16)
print(result)
# Out:
# 4
# 4
# 4.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3039731948.py in <cell line: 0>()
#       7 result = sqrt(16)
#       8 print(result)
# ----> 9 result = squre(3)
#      10 print(result)
#
# NameError: name 'squre' is not defined
