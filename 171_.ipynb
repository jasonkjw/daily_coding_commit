# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/171_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 171
price_list = [32100, 32150, 32000, 32500]
for i in range(len(price_list)):
  print(price_list[i])
# Out:
# 32100
# 32150
# 32000
# 32500

# %%
# 172
price_list = [32100, 32150, 32000, 32500]
for i in range(len(price_list)):
  print(i, price_list[i])
# Out:
# 0 32100
# 1 32150
# 2 32000
# 3 32500

# %%
# 173
price_list = [32100, 32150, 32000, 32500]
for i in range(len(price_list)):
  print((len(price_list)-1)-i, price_list[i])
# Out:
# 3 32100
# 2 32150
# 1 32000
# 0 32500

# %%
# 174
price_list = [32100, 32150, 32000, 32500]
for i in range(len(price_list)-1):
  print(100+i*10, price_list[i])
# Out:
# 100 32100
# 110 32150
# 120 32000

# %%
# 175
my_list = ["가", "나", "다", "라"]
for i in range(len(my_list)-1):
  print(my_list[i:i+2])
# Out:
# ['가', '나']
# ['나', '다']
# ['다', '라']
