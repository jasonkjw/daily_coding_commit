# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco4_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
site1 = "http://naver.com"
site2 = "http://daum.net"
site3 = "http://google.com"
site4 = "http://youtube.com"
# extrac_no1 = site1[7:-4]
extrac_no1 = site1.replace("http://","")
extrac_no1 = extrac_no1[:extrac_no1.index(".")]
print(extrac_no1)
pas1 = extrac_no1[:3] + str(len(extrac_no1)) + str(extrac_no1.count("e")) + "!"
print(f"{site1}의 비밀번호는 {pas1}입니다.")
# Out:
# naver
# http://naver.com의 비밀번호는 nav51!입니다.
