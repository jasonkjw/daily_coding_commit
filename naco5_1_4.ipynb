# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco5_1_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num_list = [5,2,4,3,1]
num_list.sort()
print(num_list)
num_list.sort(reverse=True)
print(num_list)
# Out:
# [1, 2, 3, 4, 5]
# [5, 4, 3, 2, 1]

# %%
mix_list = ["푸", 20, True]
num_list.extend(mix_list)
print(mix_list)
print(num_list)
# Out:
# ['푸', 20, True]
# [5, 4, 3, 2, 1, '푸', 20, True, '푸', 20, True]
