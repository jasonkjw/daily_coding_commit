# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco4_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("나는 %d살입니다." %20)
print("나는 %s을 좋아합니다." %"파이썬")
print("Apple은 %c로 시작해요." %"A")
print("나는 %s살 입니다." %20)
# Out:
# 나는 20살입니다.
# 나는 파이썬을 좋아합니다.
# Apple은 A로 시작해요.
# 나는 20살 입니다.

# %%
age = 20
color = "빨간"
print(f"나는 {age}살이며, {color}색을 좋아합니다.")
# Out:
# 나는 20살이며, 빨간색을 좋아합니다.
