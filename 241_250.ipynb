# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/241_250.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 241
import datetime
now = datetime.datetime.now()
print(now)
print(type(now))
# Out:
# 2026-02-08 09:27:59.683688
# <class 'datetime.datetime'>

# %%
# 242
import datetime
now = datetime.datetime.now()
print(type(now))
# Out:
# <class 'datetime.datetime'>

# %%
# 243
import datetime
now = datetime.datetime.now()
for day in range(5,0,-1):
  delta = datetime.timedelta(days=day)
  date = now - delta
  print(date)
# Out:
# 2026-02-03 09:34:46.979431
# 2026-02-04 09:34:46.979431
# 2026-02-05 09:34:46.979431
# 2026-02-06 09:34:46.979431
# 2026-02-07 09:34:46.979431

# %%
import datetime
now = datetime.datetime.now()
print(now.strftime("%H:%M:%S"))
# Out:
# 09:48:53

# %%
import datetime
day = "2020-05-04"
ret = datetime.datetime.strptime(day, "%Y-%m-%d")
print(ret,type(ret))
# Out:
# 2020-05-04 00:00:00 <class 'datetime.datetime'>

# %%
import time
import datetime

while True:
  now = datetime.datetime.now()
  print(now)
  time.sleep(1)
# Out:
# 2026-02-08 21:34:19.909913
# 2026-02-08 21:34:20.911075
# 2026-02-08 21:34:21.911403
# 2026-02-08 21:34:22.911908
# 2026-02-08 21:34:23.912226
# 2026-02-08 21:34:24.912646
# 2026-02-08 21:34:25.913027
# 2026-02-08 21:34:26.913409
# 2026-02-08 21:34:27.913835
# 2026-02-08 21:34:28.914147
# 2026-02-08 21:34:29.914473
# 2026-02-08 21:34:30.914889
# 2026-02-08 21:34:31.915211
# 2026-02-08 21:34:32.915624
# 2026-02-08 21:34:33.915943
# 2026-02-08 21:34:34.916256
# 2026-02-08 21:34:35.916658
# 2026-02-08 21:34:36.916997
# 2026-02-08 21:34:37.917379
# 2026-02-08 21:34:38.917820
# 2026-02-08 21:34:39.918157
# 2026-02-08 21:34:40.918501
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-830087155.py in <cell line: 0>()
#       5   now = datetime.datetime.now()
#       6   print(now)
# ----> 7   time.sleep(1)
#
# KeyboardInterrupt:

# %%
# 248
import os
ret = os.getcwd()
print(ret, type(ret))
# Out:
# /content <class 'str'>

# %%
#249
import os
os.rename()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2813702201.py in <cell line: 0>()
#       1 #249
#       2 import os
# ----> 3 os.rename()
#
# TypeError: rename() missing required argument 'src' (pos 1)

# %%
# 250
import numpy
for i in numpy.arange(0, 5, 0.1):
  print(i)
# Out:
# 0.0
# 0.1
# 0.2
# 0.30000000000000004
# 0.4
# 0.5
# 0.6000000000000001
# 0.7000000000000001
# 0.8
# 0.9
# 1.0
# 1.1
# 1.2000000000000002
# 1.3
# 1.4000000000000001
# 1.5
# 1.6
# 1.7000000000000002
# 1.8
# 1.9000000000000001
# 2.0
# 2.1
# 2.2
# 2.3000000000000003
# 2.4000000000000004
# 2.5
# 2.6
# 2.7
# 2.8000000000000003
# 2.9000000000000004
# 3.0
# 3.1
# 3.2
# 3.3000000000000003
# 3.4000000000000004
# 3.5
# 3.6
# 3.7
# 3.8000000000000003
# 3.9000000000000004
# 4.0
# 4.1000000000000005
# 4.2
# 4.3
# 4.4
# 4.5
# 4.6000000000000005
# 4.7
# 4.800000000000001
# 4.9
