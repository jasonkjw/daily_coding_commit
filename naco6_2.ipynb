# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco6_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for waiting_no in [1,2,3,4,5]:
  print(f"대기번호:{waiting_no}")
# Out:
# 대기번호:1
# 대기번호:2
# 대기번호:3
# 대기번호:4
# 대기번호:5

# %%
for waiting_no in range(1,6):
  print(f"대기번호:{waiting_no}")
# Out:
# 대기번호:1
# 대기번호:2
# 대기번호:3
# 대기번호:4
# 대기번호:5

# %%
for waiting_no in range(5):
  waiting_no += 1
  print(f"대기번호:{waiting_no}")
# Out:
# 대기번호:1
# 대기번호:2
# 대기번호:3
# 대기번호:4
# 대기번호:5
