# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco8_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle

profile_file = open("profile.pickle","wb")
profile = {'이름' : '스누피', '나이':30, '취미':['축구','골프','코딩']}
print(profile)

pickle.dump(profile, profile_file)
profile_file.close()

profile_file = open("profile.pickle","rb")
profile = pickle.load(profile_file)

print(profile)
profile_file.close()
# Out:
# {'이름': '스누피', '나이': 30, '취미': ['축구', '골프', '코딩']}
# {'이름': '스누피', '나이': 30, '취미': ['축구', '골프', '코딩']}
