# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/081_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 081
scores = [8.8, 8.9, 8.7, 9.2, 9.3, 9.7, 9.9, 9.5, 7.8, 9.4]
*valid_score, _, _= scores
print(valid_score)
# Out:
# [8.8, 8.9, 8.7, 9.2, 9.3, 9.7, 9.9, 9.5]

# %%
# 082
scores = [8.8, 8.9, 8.7, 9.2, 9.3, 9.7, 9.9, 9.5, 7.8, 9.4]
_, _, *valid_score = scores
print(valid_score)
# Out:
# [8.7, 9.2, 9.3, 9.7, 9.9, 9.5, 7.8, 9.4]

# %%
# 083
scores = [8.8, 8.9, 8.7, 9.2, 9.3, 9.7, 9.9, 9.5, 7.8, 9.4]
a,*valid_score, b = scores
print(valid_score)
# Out:
# [8.9, 8.7, 9.2, 9.3, 9.7, 9.9, 9.5, 7.8]

# %%
# 084
temp = {}
print(type(temp))
# Out:
# <class 'dict'>

# %%
# 085
price = {'메로나':1000, '폴라포':1200, '빵빠레':1800}
print(price)
print(price['폴라포'])
# Out:
# {'메로나': 1000, '폴라포': 1200, '빵빠레': 1800}
# 1200

# %%
# 086
price = {'메로나':1000, '폴라포':1200, '빵빠레':1800}
price['죠스바']=1200
price['월드콘']=1500
print(price)
# Out:
# {'메로나': 1000, '폴라포': 1200, '빵빠레': 1800, '죠스바': 1200, '월드콘': 1500}

# %%
# 087
ice = {'메로나': 1000,
       '폴로포': 1200,
       '빵빠레': 1800,
       '죠스바': 1200,
       '월드콘': 1500}
print("메로나 가격: ",ice['메로나'])
# Out:
# 메로나 가격:  1000

# %%
# 088
ice = {'메로나': 1000,
       '폴로포': 1200,
       '빵빠레': 1800,
       '죠스바': 1200,
       '월드콘': 1500}
del ice['메로나']
print(ice)
# Out:
# {'폴로포': 1200, '빵빠레': 1800, '죠스바': 1200, '월드콘': 1500}

# %%
# 090
icecream = {'폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
icecream['누가바'] # 딕셔너리에 없는 키를 인덱싱하면 에러 발생
