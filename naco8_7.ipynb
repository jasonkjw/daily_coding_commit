# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco8_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,51):
  with open(f"{i}주차.txt","w",encoding="utf8") as weekly_report:
    weekly_report.write(f"-{i}주차 주간보고-\n부서 : \n이름 : \n업무 요약 :")
