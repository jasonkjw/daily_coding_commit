# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
menu = ("돈가스", "치즈돈가스")
print(menu[0])
print(menu[1])
# Out:
# 돈가스
# 치즈돈가스

# %%
name = "피글렛"
age = 20
hobby = "코딩"
print(name, age, hobby)
# Out:
# 피글렛 20 코딩

# %%
(name, age, hobby) = ("피글렛", 20, "코딩")
print(name, age, hobby)
# Out:
# 피글렛 20 코딩

# %%
(departure, arrival) = ("김포", "제주")
print(departure, ">", arrival)
(departure, arrival) = (arrival, departure)
print(departure, ">", arrival)
# Out:
# 김포 > 제주
# 제주 > 김포
