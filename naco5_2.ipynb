# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cabinet = {3: "푸", 100: "피그렛"}
print(cabinet[3])
print(cabinet[100])
print(cabinet.get(3))
print(cabinet.get(4))
print("hi")
print(cabinet[4])
print("hi there")
# Out:
# 푸
# 피그렛
# 푸
# None
# hi
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2203589678.py in <cell line: 0>()
#       5 print(cabinet.get(4))
#       6 print("hi")
# ----> 7 print(cabinet[4])
#       8 print("hi there")
#
# KeyError: 4

# %%
print(cabinet.get(5, "사용가능"))
print(3 in cabinet)
print(5 in cabinet)
# Out:
# 사용가능
# True
# False

# %%
cabinet = {"A-3": "푸", "B-100":"피그렛"}
print(cabinet["A-3"])
print(cabinet["B-100"])
# Out:
# 푸
# 피그렛
