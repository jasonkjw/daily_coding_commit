# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco4_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python = "Python is Amazing"
find = python.find("n")
print(find)
find = python.index("n", find+1)
print(find)
find = python.find("java")
print(find)
# Out:
# 5
# 15
# -1

# %%
python = "Python is Amazing"
index = python.index("n")
print(index)
index = python.index("n", index+1)
print(index)
index = python.index("java")
# Out:
# 5
# 15
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-825189060.py in <cell line: 0>()
#       4 index = python.index("n", index+1)
#       5 print(index)
# ----> 6 index = python.index("java")
#
# ValueError: substring not found
