# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/exp3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
radius = 100
flag = (radius > 32)
print(flag)
# Out:
# True

# %%
expensive = price > 20000
if expensive:
  shipping_cost = 0
else :
  shipping_cost = 3000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12033/2885525383.py in <cell line: 0>()
# ----> 1 expensive = price > 20000
#       2 if expensive:
#       3   shipping_cost = 0
#       4 else :
#       5   shipping_cost = 3000
#
# NameError: name 'price' is not defined

# %%
import random
number1 = random.randint(1,100)
number2 = random.randint(1,100)

sum = number1 + number2
answer = int(input(f"{number1}+{number2}="))
flag = (answer == (sum))
print(flag)
# Out:
# 88+85=173
# True

# %%
age = int(input("age="))
result = ('minor' if age < 21 else 'adult')
print(result)
# Out:
# age=20
# minor

# %%
num=int(input("정수를 입력하세요"))
output=("짝수" if num%2==0 else "홀수")
print(output)
# Out:
# 정수를 입력하세요5
# 홀수

# %%
price = int(input("정가를 입력하세요(단위:만원)"))

if price < 100:
  sale = 0.1
elif price >= 100:
  sale = 0.15
  print("10층에서 사은품을 받아가세요.")

print(f"상품의 가격 = {price*(1-sale)}")
# Out:
# 정가를 입력하세요(단위:만원)80
# 상품의 가격 = 72.0
