# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/012.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 012
시가총액 = 2980000000000
현재가 = 50000
PER = 15.79
print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(PER,type(PER))
# Out:
# 2980000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
# 013
s = "hello"
t = "python"
print(s+"!"t)
# Out:
# hello! python

# %%
# 014
print(2+2*3)
# Out:
# 8

# %%
# 015
a = 132
print(type(a))
# Out:
# <class 'int'>

# %%
# 016
num_str = "720"
print(int(num_str))
# Out:
# 720
# 721 <class 'int'>

# %%
# 017
num = 100
num_str = str(num)
print(num_str, type(num_str))
# Out:
# 100 <class 'str'>

# %%
# 018
a = "15.79"
b = float(a)
print(b, type(b))
# Out:
# 15.79 <class 'float'>

# %%
# 019
year ="2020"
latest_years = int(year)
print(latest_years-1, latest_years, latest_years+1)
# Out:
# 2019 2020 2021

# %%
# 020
mon = int(48584)
total_price = mon * 36
print(f"{total_price:,}")
# Out:
# 1,749,024
