# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/081_100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 081
scores = [8.8, 8.9, 8.7, 9.2, 9.3, 9.7, 9.9, 9.5, 7.8, 9.4]
*valid_score, _, _= scores
print(valid_score)
# Out:
# [8.8, 8.9, 8.7, 9.2, 9.3, 9.7, 9.9, 9.5]

# %%
# 082
scores = [8.8, 8.9, 8.7, 9.2, 9.3, 9.7, 9.9, 9.5, 7.8, 9.4]
_, _, *valid_score = scores
print(valid_score)
# Out:
# [8.7, 9.2, 9.3, 9.7, 9.9, 9.5, 7.8, 9.4]

# %%
# 083
scores = [8.8, 8.9, 8.7, 9.2, 9.3, 9.7, 9.9, 9.5, 7.8, 9.4]
a,*valid_score, b = scores
print(valid_score)
# Out:
# [8.9, 8.7, 9.2, 9.3, 9.7, 9.9, 9.5, 7.8]

# %%
# 084
temp = {}
print(type(temp))
# Out:
# <class 'dict'>

# %%
# 085
price = {'메로나':1000, '폴라포':1200, '빵빠레':1800}
print(price)
print(price['폴라포'])
# Out:
# {'메로나': 1000, '폴라포': 1200, '빵빠레': 1800}
# 1200

# %%
# 086
price = {'메로나':1000, '폴라포':1200, '빵빠레':1800}
price['죠스바']=1200
price['월드콘']=1500
print(price)
# Out:
# {'메로나': 1000, '폴라포': 1200, '빵빠레': 1800, '죠스바': 1200, '월드콘': 1500}

# %%
# 087
ice = {'메로나': 1000,
       '폴로포': 1200,
       '빵빠레': 1800,
       '죠스바': 1200,
       '월드콘': 1500}
print("메로나 가격: ",ice['메로나'])
# Out:
# 메로나 가격:  1000

# %%
# 088
ice = {'메로나': 1000,
       '폴로포': 1200,
       '빵빠레': 1800,
       '죠스바': 1200,
       '월드콘': 1500}
del ice['메로나']
print(ice)
# Out:
# {'폴로포': 1200, '빵빠레': 1800, '죠스바': 1200, '월드콘': 1500}

# %%
# 090
icecream = {'폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
icecream['누가바'] # 딕셔너리에 없는 키를 인덱싱하면 에러 발생

# %%
# 091
inventory = {'메로나':[300,200],
             '비비빅':[400,3],
             '죠스바':[250,100]}
print(inventory)
# Out:
# {'메로나': [300, 200], '비비빅': [400, 3], '죠스바': [250, 100]}

# %%
# 092
inventory = {"메로나": [300, 20],
              "비비빅": [400, 3],
              "죠스바": [250, 100]}
print(inventory['메로나'][0],'원')
# Out:
# 300 원

# %%
# 093
inventory = {"메로나": [300, 20],
              "비비빅": [400, 3],
              "죠스바": [250, 100]}
print(inventory['메로나'][1], '개')
# Out:
# 20 개

# %%
# 094
inventory = {"메로나": [300, 20],
              "비비빅": [400, 3],
              "죠스바": [250, 100]}
inventory['월드콘']=[500,7]
print(inventory)
# Out:
# {'메로나': [300, 20], '비비빅': [400, 3], '죠스바': [250, 100], '월드콘': [500, 7]}

# %%
# 095
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
print(icecream.keys())
# Out:
# dict_keys(['탱크보이', '폴라포', '빵빠레', '월드콘', '메로나'])

# %%
# 096
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
print(icecream.values())
# Out:
# dict_values([1200, 1200, 1800, 1500, 1000])

# %%
# 097
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
print(sum(icecream.values()))
# Out:
# 6700

# %%
# 098
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
new_product = {'팥빙수':2700, '아맛나':1000}
icecream.update(new_product)
print(icecream)
# Out:
# {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000, '팥빙수': 2700, '아맛나': 1000}

# %%
# 099
keys = ("apple", "pear", "peach")
vals = (300, 250, 400)
result = dict(zip(keys, vals))
print(result)
# Out:
# {'apple': 300, 'pear': 250, 'peach': 400}

# %%
# 100
date = ['09/05', '09/06', '09/07', '09/08', '09/09']
close_price = [10500, 10300, 10100, 10800, 11000]
result = dict(zip(date, close_price))
print(result)
# Out:
# {'09/05': 10500, '09/06': 10300, '09/07': 10100, '09/08': 10800, '09/09': 11000}
