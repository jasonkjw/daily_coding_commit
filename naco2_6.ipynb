# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco2_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 실습문제
station = '사당'
print(f"{station}행 열차가 들어오고 있습니다")
station = '신도림'
print(f"{station}행 열차가 들어오고 있습니다")
station = '인천공항'
print(f"{station}행 열차가 들어오고 있습니다")
# Out:
# 사당행 열차가 들어오고 있습니다
# 신도림행 열차가 들어오고 있습니다
# 인천공항행 열차가 들어오고 있습니다
