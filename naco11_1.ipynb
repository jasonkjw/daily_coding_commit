# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco11_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys

module_path = '/content/drive/MyDrive/Colab Notebooks'

if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import theater_module

theater_module.price(3)
theater_module.price_morning(4)
theater_module.price_soldier(5)
# Out:
# 3명, 영화표 가격은 30000원입니다.
# 4명, 조조 할인 영화표 가격은 24000원입니다.
# 5명, 군인 할인 영화표 가격은 20000원입니다.

# %%
from theater_module import *

price(3)
price_morning(4)
price_soldier(5)
# Out:
# 3명, 영화표 가격은 30000원입니다.
# 4명, 조조 할인 영화표 가격은 24000원입니다.
# 5명, 군인 할인 영화표 가격은 20000원입니다.

# %%
from theater_module import price, price_morning
price(5)
price_morning(6)
# Out:
# 5명, 영화표 가격은 50000원입니다.
# 6명, 조조 할인 영화표 가격은 36000원입니다.

# %%
from theater_module import price_soldier as price
price_soldier(3)
# Out:
# 3명, 군인 할인 영화표 가격은 12000원입니다.

# %%
import travel.thailand

trip_to = travel.thailand.ThailandPackage()
trip_to.detail()
# Out:
# [태국 3박 5일 패키지] 방콕, 파타야 여행(야시장 투어) 50만 원

# %%
from travel.thailand import ThailandPackage

trip_to = ThailandPackage()
trip_to.detail()
# Out:
# [태국 3박 5일 패키지] 방콕, 파타야 여행(야시장 투어) 50만 원

# %%
from travel import vietnam

trip_to = vietnam.VietnamPackage()
trip_to.detail()
# Out:
# [베트남 3박 5일 패키지] 다낭 효도 여행 60만 원

# %%
from travel import *

trip_to = vietnam.VietnamPackage()
trip_to.detail()
# Out:
# [베트남 3박 5일 패키지] 다낭 효도 여행 60만 원

# %%
from travel import *

trip_to = thailand.ThailandPackage()
trip_to.detail()
# Out:
# [태국 3박 5일 패키지] 방콕, 파타야 여행(야시장 투어) 50만 원
