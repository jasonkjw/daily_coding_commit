# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco5_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
menu = {"커피", "주스", "우유"}
print(menu)
print(type(menu))
menu = list(menu)
print(menu, type(menu))
menu = tuple(menu)
print(menu, type(menu))
menu = set(menu)
print(menu, type(menu))
# Out:
# {'주스', '우유', '커피'}
# <class 'set'>
# ['주스', '우유', '커피'] <class 'list'>
# ('주스', '우유', '커피') <class 'tuple'>
# {'주스', '우유', '커피'} <class 'set'>
