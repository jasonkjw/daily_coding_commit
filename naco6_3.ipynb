# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco6_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

count = 0
for customers in range(1,51):
  time = random.randint(5,50)
  if 5<= time <= 15 :
    matching = 0
    count += 1
  else : matching = " "
  print(f"[{matching}], {customers}번째 손님 (소요시간 : {time}분)")
print(f"총 탑승객 : {count}명")
# Out:
# [ ], 1번째 손님 (소요시간 : 23분)
# [ ], 2번째 손님 (소요시간 : 34분)
# [0], 3번째 손님 (소요시간 : 13분)
# [0], 4번째 손님 (소요시간 : 5분)
# [ ], 5번째 손님 (소요시간 : 22분)
# [ ], 6번째 손님 (소요시간 : 35분)
# [ ], 7번째 손님 (소요시간 : 26분)
# [ ], 8번째 손님 (소요시간 : 50분)
# [ ], 9번째 손님 (소요시간 : 31분)
# [ ], 10번째 손님 (소요시간 : 33분)
# [ ], 11번째 손님 (소요시간 : 33분)
# [ ], 12번째 손님 (소요시간 : 18분)
# [ ], 13번째 손님 (소요시간 : 27분)
# [0], 14번째 손님 (소요시간 : 8분)
# [ ], 15번째 손님 (소요시간 : 42분)
# [ ], 16번째 손님 (소요시간 : 46분)
# [ ], 17번째 손님 (소요시간 : 16분)
# [ ], 18번째 손님 (소요시간 : 22분)
# [0], 19번째 손님 (소요시간 : 10분)
# [ ], 20번째 손님 (소요시간 : 18분)
# [ ], 21번째 손님 (소요시간 : 44분)
# [ ], 22번째 손님 (소요시간 : 33분)
# [0], 23번째 손님 (소요시간 : 11분)
# [ ], 24번째 손님 (소요시간 : 30분)
# [ ], 25번째 손님 (소요시간 : 42분)
# [ ], 26번째 손님 (소요시간 : 16분)
# [0], 27번째 손님 (소요시간 : 14분)
# [ ], 28번째 손님 (소요시간 : 32분)
# [ ], 29번째 손님 (소요시간 : 37분)
# [ ], 30번째 손님 (소요시간 : 47분)
# [ ], 31번째 손님 (소요시간 : 37분)
# [ ], 32번째 손님 (소요시간 : 45분)
# [ ], 33번째 손님 (소요시간 : 34분)
# [0], 34번째 손님 (소요시간 : 12분)
# [ ], 35번째 손님 (소요시간 : 19분)
# [ ], 36번째 손님 (소요시간 : 46분)
# ...
