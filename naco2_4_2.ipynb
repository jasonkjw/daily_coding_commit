# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/naco2_4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = '연탄이'
aninal = '개'
age = 4
hobby = '산책'
print("반려동물을 소개해 주세요")
print("우리 집 반려동물은 개인데, 이름이 연탄이예요")
print("연탄이는 4살이고, 산책을 아주 좋아해요")
# Out:
# 반려동물을 소개해 주세요
# 우리 집 반려동물은 개인데, 이름이 연탄이예요
# 연탄이는 4살이고, 산책을 아주 좋아해요

# %%
name = '연탄이'
animal = '개'
age = 4
hobby = '산책'
print("반려동물을 소개해 주세요")
print("우리 집 반려동물은 " + animal + "인데, 이름이 " + name +"예요")
print(name +"는 " + str(age) + "살이고, " + hobby + "을 아주 좋아해요")
# Out:
# 반려동물을 소개해 주세요
# 우리 집 반려동물은 개인데, 이름이연탄이이예요
# 연탄이는 4살이고, 산책을 아주 좋아해요

# %%
name = '해피'
animal = '고양이'
age = 4
hobby = '낮잠'
print("반려동물을 소개해 주세요")
print("우리 집 반려동물은 " + animal + "인데, 이름이 " + name +"예요")
print(name +"는 " + str(age) + "살이고, " + hobby + "을 아주 좋아해요")
# Out:
# 반려동물을 소개해 주세요
# 우리 집 반려동물은 고양이인데, 이름이 해피이예요
# 해피는 4살이고, 낮잠을 아주 좋아해요

# %%
name = '연탄이'
animal = '개'
age = 4
hobby = '산책'
print("반려동물을 소개해 주세요")
print("우리 집 반려동물은 ", animal, "인데, 이름이 ", name,"예요")
print(name,"는 ", str(age), "살이고, ", hobby, "을 아주 좋아해요")
# Out:
# 반려동물을 소개해 주세요
# 우리 집 반려동물은  개 인데, 이름이  연탄이 예요
# 연탄이 는  4 살이고,  산책 을 아주 좋아해요

# %%
name = '연탄이'
animal = '개'
age = 4
hobby = '산책'
print("반려동물을 소개해 주세요")
print(f"우리 집 반려동물은 {animal}인데, 이름이 {name}예요")
print(f"{name}는 {age}살이고, {hobby}을 아주 좋아해요")
# Out:
# 반려동물을 소개해 주세요
# 우리 집 반려동물은 개인데, 이름이 연탄이예요
# 연탄이는 4살이고, 산책을 아주 좋아해요
