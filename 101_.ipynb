# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/101_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 101
bool
# Out:
# bool

# %%
# 102
print(3 == 5)
# False
# Out:
# False

# %%
# 103
print(3 < 5)
# True
# Out:
# True

# %%
# 104
x = 4
print(1 < x < 5)
# True
# Out:
# True

# %%
# 105
print ((3 == 3) and (4 != 3))
# True
# Out:
# True

# %%
# 106
# print(3 => 4)
print(3 >= 4)
# Out:
# False

# %%
# 107
if 4 < 3:
    print("Hello World")
# nothing

# %%
# 108
if 4 < 3:
    print("Hello World.")
else:
    print("Hi, there.")
# Hi, there.
# Out:
# Hi, there.

# %%
# 109
if True :
    print ("1")
    print ("2")
else :
    print("3")
print("4")
# Out:
# 1
# 2
# 4

# %%
# 110
if True :
    if False:
        print("1")
        print("2")
    else:
        print("3")
else :
    print("4")
print("5")
# Out:
# 3
# 5
