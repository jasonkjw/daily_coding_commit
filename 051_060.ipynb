# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonkjw/daily_coding_commit/blob/main/051_060.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 051
movie_list=[ ]
movie_list.append("닥터 스트레인지")
movie_list.append("스플릿")
movie_list.append("럭키")
print(movie_list)
# Out:
# ['닥터 스트레인지', '스플릿', '럭키']

# %%
#052
movie_list.append("배트맨")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3095716409.py in <cell line: 0>()
#       1 #052
# ----> 2 movie_list.append(1,"배트맨")
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
#053
movie_rank = ['닥터 스트레인지', '스플릿', '럭키', '배트맨']
movie_rank.insert(1, "슈머맨")
print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈머맨', '스플릿', '럭키', '배트맨']

# %%
#054
movie_rank = ['닥터 스트레인지', '슈퍼맨', '스플릿', '럭키', '배트맨']
del movie_rank[3]
print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈퍼맨', '스플릿', '배트맨']

# %%
# 055
movie_rank = ['닥터 스트레인지', '슈퍼맨', '스플릿', '배트맨']
del movie_rank[1]
print(movie_rank)
del movie_rank[1]
print(movie_rank)
# Out:
# ['닥터 스트레인지', '스플릿', '배트맨']
# ['닥터 스트레인지', '배트맨']

# %%
# 056
lang1 = ["C", "C++", "JAVA"]
lang2 = ["Python", "Go", "C#"]
lans = lang1 + lang2
print(lans)
# Out:
# ['C', 'C++', 'JAVA', 'Python', 'Go', 'C#']

# %%
# 057
nums = [1, 2, 3, 4, 5, 6, 7]
print("max: ", max(nums))
print("min: ", min(nums))
# Out:
# max:  7
# min:  1

# %%
# 058
nums = [1, 2, 3, 4, 5]
print(sum(nums))
# Out:
# 15

# %%
# 059
cook = ["피자", "김밥", "만두", "양념치킨", "족발", "피자", "김치만두", "쫄면", "소시지", "라면", "팥빙수", "김치전"]
print(len(cook))
# Out:
# 12

# %%
# 060
nums = [1, 2, 3, 4, 5]
print(sum(nums)/len(nums))
# Out:
# 3.0
